# %% [markdown]
# # Debug Test Notebook
#
# This notebook tests error analysis with repo-local tracebacks.

# %%
from src.utils.helpers import validate_input

# %%
validate_input("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 validate_input("")
# File src/utils/helpers.py:12, in validate_input(value)
#      10 """Validate that input is non-empty."""
#      11 if not value or not value.strip():
# ---> 12     raise ValueError("Input must not be empty")
# ValueError: Input must not be empty

# %%
x = 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = 1 / 0
# ZeroDivisionError: division by zero
