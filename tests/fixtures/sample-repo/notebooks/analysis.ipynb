# %% [markdown]
# # Sample Analysis
#
# This notebook demonstrates basic data processing.

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head(15)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9
# 3    10    11    12
# 4    13    14    15
# 5    16    17    18
# 6    19    20    21
# 7    22    23    24
# 8    25    26    27
# 9    28    29    30
# 10   31    32    33
# 11   34    35    36
# 12   37    38    39

# %%
df.invalid_method()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.invalid_method()
# AttributeError: 'DataFrame' object has no attribute 'invalid_method'

# %%
x = 42

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3])
plt.show()

# %% [raw]
# Raw cell content here.
